# %% [markdown]
# # Working with, and analysing, reaction time data
#
# In this notebook, I will look to take RT data and plot it's main metrics (i.e. KDF, CDF, etc...). For this, I will be using the tutorial provided by Eric Marsja (http://www.pybloggers.com/2016/08/exploring-response-time-distributions-using-python/)
#
# ## Setup workspace
# ### Import libraries

# %%
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import data
# Here we import example data from a flanker task (stored in csv style) as a data frame.

# %%
frame = pd.read_csv('./data/flanks.csv', sep=',')

# %% [markdown]
# ## Kernel Density Estimation

# %%
from rt_functions import kde_plot
kde_plot(frame, ['incongruent', 'congruent'], 'RT', 'TrialType', save_file=False)

# %% [markdown]
# ## Cumulative Distribution Function

# %%
from rt_functions import cdf, cdf_plot # Import CDF functions from the independent rt_functions script

cdf_data = cdf(frame, conditions=['incongruent', 'congruent']) # Extract CDF data from data frame
cdf_plot(cdf_data, legend=True, save_file=False) # Plot the extracted CDF data
# Out:
# /Users/stevenerrington/opt/anaconda3/envs/learn-python/lib/python3.9/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
